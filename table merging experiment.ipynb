# %%
import pandas as pd
df1=pd.read_csv('table1_1.csv')
df2=pd.read_csv('table1_2.csv')
df3=pd.read_csv('table1_3.csv')
df4=pd.read_csv('table1_4.csv')

# %%
Table1 = pd.concat([df1, df2,df3,df4], ignore_index=True)

# %%
Table1
# Out:
#      SNo Brandname                     Category       Price  \
# 0      1    Adidas                Men • Cricket     ₹999.00
# 1      2    Adidas               Men • Football   ₹5 299.00
# 2      3    Adidas  Men • Fear of God Athletics  ₹18 999.00
# 3      4    Adidas  Men • Fear of God Athletics  ₹16 999.00
# 4      5    Adidas  Men • Fear of God Athletics  ₹21 999.00
# ..   ...       ...                          ...         ...
# 573  574    Adidas             Men • Sportswear   ₹3 299.00
# 574  575    Adidas              Women • Running   ₹3 999.00
# 575  576    Adidas                   Men • Swim   ₹2 299.00
# 576  577    Adidas              Men • Originals   ₹5 599.00
# 577  578    Adidas            Women • Originals   ₹4 599.00
#
#                                     ProductName                     occasion  \
# 0                  INDIA CRICKET ODI FAN JERSEY                Men • Cricket
# 1                 REAL MADRID 23/24 HOME JERSEY               Men • Football
# ...
